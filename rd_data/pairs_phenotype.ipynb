# %%
import pandas as pd
import numpy as np
import random

# %%
# read hpo, orphanet_code and disease information
df = pd.read_csv('hpo_id_orpha.csv')
df
# Out:
#         orphanet_code                                       disease_name  \
# 0                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# 1                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# 2                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# 3                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# 4                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# ...               ...                                                ...
# 114044         658549                 Idiopathic small fibers neuropathy
# 114045         658549                 Idiopathic small fibers neuropathy
# 114046         658549                 Idiopathic small fibers neuropathy
# 114047         658549                 Idiopathic small fibers neuropathy
# 114048         658549                 Idiopathic small fibers neuropathy
#
#             hpo_id
# 0       HP:0001249
# 1       HP:0001939
# 2       HP:0011968
# 3       HP:0000532
# 4       HP:0000533
# ...            ...
# 114044  HP:0007550
# 114045  HP:0008652
# 114046  HP:0002579
# 114047  HP:0032147
# 114048  HP:0012700
#
# [114049 rows x 3 columns]

# %%
# Dropping duplicate rows based on "orphanet_code" and keeping the first occurrence
df = df.drop_duplicates(subset="orphanet_code")
df = df.drop(columns = "hpo_id")
df
# Out:
#         orphanet_code                                       disease_name
# 0                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# 25                  6        3-methylcrotonyl-CoA carboxylase deficiency
# 35                  7                                        3C syndrome
# 99                  8                                    47,XYY syndrome
# 144                 9                                        Tetrasomy X
# ...               ...                                                ...
# 113858         592574                            Menke-Hennekam syndrome
# 113902         596448                      IgG4-related systemic disease
# 113932         599373                      STXBP1-related encephalopathy
# 113963         647799  MYT1L-related developmental delay-intellectual...
# 114027         658549                 Idiopathic small fibers neuropathy
#
# [4256 rows x 2 columns]

# %%
# read the orphanet code and hpoid of pairs information
df_orpha_hposet = pd.read_csv('pairs_orphacode_hposet.csv')
df_orpha_hposet
# Out:
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 1            15                                     Achondroplasia
# 2            18                      Distal renal tubular acidosis
# 3            18                      Distal renal tubular acidosis
# 4            41              Dyschromatosis symmetrica hereditaria
# ...         ...                                                ...
# 2589     542310  Leukoencephalopathy with calcifications and cysts
# 2590     544469               PRUNE1-related neurological syndrome
# 2591     544469               PRUNE1-related neurological syndrome
# 2592     565624  Combined oxidative phosphorylation defect type 39
# 2593     565624  Combined oxidative phosphorylation defect type 39
#
#                                                 HPO_ALL
# 0     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 1     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 2     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 3     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 4        HP:0012733; HP:0001304; HP:0011509; HP:0007988
# ...                                                 ...
# 2589  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2590  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2591  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2592  HP:0000028; HP:0011344; HP:0007371; HP:0006956...
# 2593  HP:0000028; HP:0011344; HP:0007371; HP:0006956...
#
# [2594 rows x 3 columns]

# %%
# Merging the data based on the 'ORPHACODE' and 'orphanet_code' columns
df_merged = pd.merge(df_orpha_hposet, df, left_on='ORPHACODE', right_on='orphanet_code', how='inner')

# Display the merged DataFrame
df_merged
# Out:
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 1            15                                     Achondroplasia
# 2            18                      Distal renal tubular acidosis
# 3            18                      Distal renal tubular acidosis
# 4            41              Dyschromatosis symmetrica hereditaria
# ...         ...                                                ...
# 2589     542310  Leukoencephalopathy with calcifications and cysts
# 2590     544469               PRUNE1-related neurological syndrome
# 2591     544469               PRUNE1-related neurological syndrome
# 2592     565624  Combined oxidative phosphorylation defect type 39
# 2593     565624  Combined oxidative phosphorylation defect type 39
#
#                                                 HPO_ALL  orphanet_code  \
# 0     HP:0001513; HP:0000463; HP:0011867; HP:0000238...             15
# 1     HP:0001513; HP:0000463; HP:0011867; HP:0000238...             15
# 2     HP:0000114; HP:0011964; HP:0002013; HP:0004396...             18
# 3     HP:0000114; HP:0011964; HP:0002013; HP:0004396...             18
# 4        HP:0012733; HP:0001304; HP:0011509; HP:0007988             41
# ...                                                 ...            ...
# 2589  HP:0100320; HP:0100543; HP:0001260; HP:0002516...         542310
# 2590  HP:0002540; HP:0000347; HP:0001285; HP:0001639...         544469
# 2591  HP:0002540; HP:0000347; HP:0001285; HP:0001639...         544469
# 2592  HP:0000028; HP:0011344; HP:0007371; HP:0006956...         565624
# 2593  HP:0000028; HP:0011344; HP:0007371; HP:0006956...         565624
#
#                                            disease_name
# 0                                        Achondroplasia
# 1                                        Achondroplasia
# 2                         Distal renal tubular acidosis
# 3                         Distal renal tubular acidosis
# 4                 Dyschromatosis symmetrica hereditaria
# ...                                                 ...
# 2589  Leukoencephalopathy with calcifications and cysts
# 2590               PRUNE1-related neurological syndrome
# 2591               PRUNE1-related neurological syndrome
# 2592  Combined oxidative phosphorylation defect type 39
# 2593  Combined oxidative phosphorylation defect type 39
#
# [2594 rows x 5 columns]

# %%
# Extract the three columns (ORPHACODE', 'disease_name', 'HPO_ALL')
df_pairs_hposet = df_merged[['ORPHACODE', 'disease_name', 'HPO_ALL']]
print(df_pairs_hposet.head())
# Out:
#    ORPHACODE                           disease_name  \
# 0         15                         Achondroplasia
# 1         15                         Achondroplasia
# 2         18          Distal renal tubular acidosis
# 3         18          Distal renal tubular acidosis
# 4         41  Dyschromatosis symmetrica hereditaria
#
#                                              HPO_ALL
# 0  HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 1  HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 2  HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 3  HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 4     HP:0012733; HP:0001304; HP:0011509; HP:0007988

# %%
df_pairs_hposet = df_pairs_hposet.rename(columns={"disease_name": "DISEASE"})
df_pairs_hposet
# Out:
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 1            15                                     Achondroplasia
# 2            18                      Distal renal tubular acidosis
# 3            18                      Distal renal tubular acidosis
# 4            41              Dyschromatosis symmetrica hereditaria
# ...         ...                                                ...
# 2589     542310  Leukoencephalopathy with calcifications and cysts
# 2590     544469               PRUNE1-related neurological syndrome
# 2591     544469               PRUNE1-related neurological syndrome
# 2592     565624  Combined oxidative phosphorylation defect type 39
# 2593     565624  Combined oxidative phosphorylation defect type 39
#
#                                                 HPO_ALL
# 0     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 1     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 2     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 3     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 4        HP:0012733; HP:0001304; HP:0011509; HP:0007988
# ...                                                 ...
# 2589  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2590  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2591  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2592  HP:0000028; HP:0011344; HP:0007371; HP:0006956...
# 2593  HP:0000028; HP:0011344; HP:0007371; HP:0006956...
#
# [2594 rows x 3 columns]

# %%
# Extract the first two columns (ORPHACODE, DISEASE)
df_orpha_disease = df_pairs_hposet[['ORPHACODE', 'DISEASE']]
# Save to a csv file
df_orpha_disease.to_csv("paire_orphacode_disease.csv", index=False)

# %%
df_pairs_hposet
# Out:
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 1            15                                     Achondroplasia
# 2            18                      Distal renal tubular acidosis
# 3            18                      Distal renal tubular acidosis
# 4            41              Dyschromatosis symmetrica hereditaria
# ...         ...                                                ...
# 2589     542310  Leukoencephalopathy with calcifications and cysts
# 2590     544469               PRUNE1-related neurological syndrome
# 2591     544469               PRUNE1-related neurological syndrome
# 2592     565624  Combined oxidative phosphorylation defect type 39
# 2593     565624  Combined oxidative phosphorylation defect type 39
#
#                                                 HPO_ALL
# 0     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 1     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 2     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 3     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 4        HP:0012733; HP:0001304; HP:0011509; HP:0007988
# ...                                                 ...
# 2589  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2590  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2591  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2592  HP:0000028; HP:0011344; HP:0007371; HP:0006956...
# 2593  HP:0000028; HP:0011344; HP:0007371; HP:0006956...
#
# [2594 rows x 3 columns]

# %%
# Save to a csv file
df_pairs_hposet.to_csv("pairs_orphacode_hposet.csv", index=False)

# %%
# Define the function with file-saving capability
def pairs_phenotypes(n, m):
    
    # Read the file into a DataFrame, assuming it is tab-separated
    df = pd.read_csv('pairs_orphacode_hposet.csv')
    
    # Ensure n and m are within the specified limits
    n = min(n, 1184)
    m = min(m, 1410)
    
    # Extract first n rows and last m rows
    rows_extracted = pd.concat([df.head(n), df.tail(m)])
    
    # Save the result to a txt file
    rows_extracted.to_csv('pairs_phenotypes.csv')
    
    print(rows_extracted.head())
    print("File saved as 'pairs_phenotypes.csv'")
    
    return rows_extracted

# %%
df_paris_phenotypes = pairs_phenotypes(n=20, m=20)
print(df_paris_phenotypes)
# Out:
#    ORPHACODE                                DISEASE  \
# 0         15                         Achondroplasia
# 1         15                         Achondroplasia
# 2         18          Distal renal tubular acidosis
# 3         18          Distal renal tubular acidosis
# 4         41  Dyschromatosis symmetrica hereditaria
#
#                                              HPO_ALL
# 0  HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 1  HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 2  HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 3  HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 4     HP:0012733; HP:0001304; HP:0011509; HP:0007988
# File saved as 'pairs_phenotypes.csv'
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 1            15                                     Achondroplasia
# 2            18                      Distal renal tubular acidosis
# 3            18                      Distal renal tubular acidosis
# 4            41              Dyschromatosis symmetrica hereditaria
# 5            41              Dyschromatosis symmetrica hereditaria
# 6            51                         Aicardi-Goutières syndrome
# 7            51                         Aicardi-Goutières syndrome
# 8            53                     Albers-Schönberg osteopetrosis
# 9            53                     Albers-Schönberg osteopetrosis
# 10           58                                  Alexander disease
# 11           58                                  Alexander disease
# 12           63                                    Alport syndrome
# 13           63                                    Alport syndrome
# 14           65                         Leber congenital amaurosis
# 15           65                         Leber congenital amaurosis
# 16           82  Hereditary thrombophilia due to congenital ant...
# 17           82  Hereditary thrombophilia due to congenital ant...
# 18           87                                     Apert syndrome
# 19           87                                     Apert syndrome
# 2574     521406   Dystonia-parkinsonism-hypermanganesemia syndrome
# 2575     521406   Dystonia-parkinsonism-hypermanganesemia syndrome
# 2576     527497  NKX6-2-related autosomal recessive hypomyelina...
# 2577     527497  NKX6-2-related autosomal recessive hypomyelina...
# 2578     529665  Neurodevelopmental delay-seizures-ophthalmic a...
# 2579     529665  Neurodevelopmental delay-seizures-ophthalmic a...
# 2580     536467  B3GALT6-related spondylodysplastic Ehlers-Danl...
# 2581     536467  B3GALT6-related spondylodysplastic Ehlers-Danl...
# 2582     536532       Classical-like Ehlers-Danlos syndrome type 2
# 2583     536532       Classical-like Ehlers-Danlos syndrome type 2
# 2584     541423  Growth delay-intellectual disability-hepatopat...
# 2585     541423  Growth delay-intellectual disability-hepatopat...
# 2586     542306  GNB5-related intellectual disability-cardiac a...
# 2587     542306  GNB5-related intellectual disability-cardiac a...
# 2588     542310  Leukoencephalopathy with calcifications and cysts
# 2589     542310  Leukoencephalopathy with calcifications and cysts
# 2590     544469               PRUNE1-related neurological syndrome
# 2591     544469               PRUNE1-related neurological syndrome
# 2592     565624  Combined oxidative phosphorylation defect type 39
# 2593     565624  Combined oxidative phosphorylation defect type 39
#
#                                                 HPO_ALL
# 0     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 1     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 2     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 3     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 4        HP:0012733; HP:0001304; HP:0011509; HP:0007988
# 5        HP:0012733; HP:0001304; HP:0011509; HP:0007988
# 6     HP:0007052; HP:0002071; HP:0001288; HP:0002187...
# 7     HP:0007052; HP:0002071; HP:0001288; HP:0002187...
# 8     HP:0005789; HP:0000365; HP:0000648; HP:0000618...
# 9     HP:0005789; HP:0000365; HP:0000648; HP:0000618...
# 10    HP:0002383; HP:0000826; HP:0000822; HP:0001337...
# 11    HP:0002383; HP:0000826; HP:0000822; HP:0001337...
# 12    HP:0011488; HP:0006756; HP:0002837; HP:0012576...
# 13    HP:0011488; HP:0006756; HP:0002837; HP:0012576...
# 14    HP:0001249; HP:0001250; HP:0004374; HP:0001252...
# 15    HP:0001249; HP:0001250; HP:0004374; HP:0001252...
# 16    HP:0040246; HP:0002638; HP:0001976; HP:0002204...
# 17    HP:0040246; HP:0002638; HP:0001976; HP:0002204...
# 18    HP:0000244; HP:0000444; HP:0001770; HP:0009601...
# 19    HP:0000244; HP:0000444; HP:0001770; HP:0009601...
# 2574  HP:0002059; HP:0032097; HP:0001332; HP:0011448...
# 2575  HP:0002059; HP:0032097; HP:0001332; HP:0011448...
# 2576  HP:0003429; HP:0000571; HP:0002079; HP:0000639...
# 2577  HP:0003429; HP:0000571; HP:0002079; HP:0000639...
# 2578  HP:0000505; HP:0001272; HP:0000316; HP:0002133...
# 2579  HP:0000505; HP:0001272; HP:0000316; HP:0002133...
# 2580  HP:0001252; HP:0003414; HP:0002091; HP:0002779...
# 2581  HP:0001252; HP:0003414; HP:0002091; HP:0002779...
# 2582  HP:0001488; HP:0001270; HP:0006439; HP:0001852...
# 2583  HP:0001488; HP:0001270; HP:0006439; HP:0001852...
# 2584  HP:0100511; HP:0002719; HP:0006129; HP:0001399...
# 2585  HP:0100511; HP:0002719; HP:0006129; HP:0001399...
# 2586  HP:0002521; HP:0001344; HP:0000639; HP:0011675...
# 2587  HP:0002521; HP:0001344; HP:0000639; HP:0011675...
# 2588  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2589  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2590  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2591  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2592  HP:0000028; HP:0011344; HP:0007371; HP:0006956...
# 2593  HP:0000028; HP:0011344; HP:0007371; HP:0006956...

# %%
# Function to randomly select n HPO terms from the HPOALL column in df_pairs_hposet
def pairs_hpo(i, n, m):
    
    # read the orphanet code and hpoid of pairs information
    df_pairs_hposet = pd.read_csv('pairs_phenotypes.csv')
    
    def random_hpo(hpo_str, i):
        # Split the HPO terms by "; " and randomly select n terms
        hpo_terms = hpo_str.split("; ")
        selected_terms = random.sample(hpo_terms, min(i, len(hpo_terms)))  # limit to available terms
        return "; ".join(selected_terms)
    
    # Function to select random HPO terms from a string
    def random_hpo_noise(hpo_str, num_terms):
        # Split the HPO terms by "; " and randomly select the specified number of terms
        hpo_terms = hpo_str.split("; ")
        selected_terms = random.sample(hpo_terms, min(num_terms, len(hpo_terms)))  # limit to available terms
        return selected_terms
   
    # read all the hpo term
    df_all_hpo = pd.read_csv('hpo_id_all.csv')
    
    # Convert df_all_hpo 'hpo_id' column to a list of all HPO terms
    all_hpo_terms = df_all_hpo['hpo_id'].tolist()
    
    # Apply the function to create the HPO_NOISE column in df_pairs_hposet
    def combine_hpo_noise(row):
        # Select n terms from the HPO_ALL column in df_pairs_hposet
        selected_hpo_all = random_hpo_noise(row['HPO_ALL'], n)
        # Select m terms from the df_all_hpo HPO list
        selected_hpo_noise = random.sample(all_hpo_terms, min(m, len(all_hpo_terms)))
        # Combine and return as a single string with "; " delimiter
        return "; ".join(selected_hpo_all + selected_hpo_noise)

    # Apply the function to each row in df_pairs_hposet
    df_pairs_hposet[f'HPO_{i}'] = df_pairs_hposet['HPO_ALL'].apply(lambda x: random_hpo(x, i))    

    # Add the new column HPO_NOISE to df_pairs_hposet
    df_pairs_hposet['HPO_NOISE'] = df_pairs_hposet.apply(combine_hpo_noise, axis=1)
    
    # Save the result to a csv file
    df_pairs_hposet.to_csv('pairs_hpo.csv')

    print(df_pairs_hposet.head())
    print("File saved as 'pairs_hpo.csv'")
    
    return df_pairs_hposet

# %%
# Example usage (assuming df_pairs_hposet and df_all_hpo are defined):
df_pairs_hposet = pairs_hpo(i=5, n=3, m=2)
print(df_pairs_hposet)
# Out:
#    Unnamed: 0  ORPHACODE                                DISEASE  \
# 0           0         15                         Achondroplasia
# 1           1         15                         Achondroplasia
# 2           2         18          Distal renal tubular acidosis
# 3           3         18          Distal renal tubular acidosis
# 4           4         41  Dyschromatosis symmetrica hereditaria
#
#                                              HPO_ALL  \
# 0  HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 1  HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 2  HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 3  HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 4     HP:0012733; HP:0001304; HP:0011509; HP:0007988
#
#                                                HPO_5  \
# 0  HP:0005619; HP:0009826; HP:0005819; HP:0008905...
# 1  HP:0003498; HP:0000256; HP:0000365; HP:0004060...
# 2  HP:0002014; HP:0011964; HP:0002013; HP:0011387...
# 3  HP:0002014; HP:0001510; HP:0003126; HP:0000128...
# 4     HP:0012733; HP:0007988; HP:0001304; HP:0011509
#
#                                            HPO_NOISE
# 0  HP:0005819; HP:0008947; HP:0010536; HP:0010622...
# 1  HP:0008947; HP:0045086; HP:0045087; HP:0003097...
# 2  HP:0002900; HP:0002013; HP:0003126; HP:0031728...
# 3  HP:0001878; HP:0001996; HP:0001508; HP:0004889...
# 4  HP:0012733; HP:0011509; HP:0007988; HP:0100703...
# File saved as 'pairs_hpo.csv'
#     Unnamed: 0  ORPHACODE                                            DISEASE  \
# 0            0         15                                     Achondroplasia
# 1            1         15                                     Achondroplasia
# 2            2         18                      Distal renal tubular acidosis
# 3            3         18                      Distal renal tubular acidosis
# 4            4         41              Dyschromatosis symmetrica hereditaria
# 5            5         41              Dyschromatosis symmetrica hereditaria
# 6            6         51                         Aicardi-Goutières syndrome
# 7            7         51                         Aicardi-Goutières syndrome
# 8            8         53                     Albers-Schönberg osteopetrosis
# 9            9         53                     Albers-Schönberg osteopetrosis
# 10          10         58                                  Alexander disease
# 11          11         58                                  Alexander disease
# 12          12         63                                    Alport syndrome
# 13          13         63                                    Alport syndrome
# 14          14         65                         Leber congenital amaurosis
# 15          15         65                         Leber congenital amaurosis
# 16          16         82  Hereditary thrombophilia due to congenital ant...
# 17          17         82  Hereditary thrombophilia due to congenital ant...
# 18          18         87                                     Apert syndrome
# 19          19         87                                     Apert syndrome
# 20        2574     521406   Dystonia-parkinsonism-hypermanganesemia syndrome
# 21        2575     521406   Dystonia-parkinsonism-hypermanganesemia syndrome
# 22        2576     527497  NKX6-2-related autosomal recessive hypomyelina...
# 23        2577     527497  NKX6-2-related autosomal recessive hypomyelina...
# 24        2578     529665  Neurodevelopmental delay-seizures-ophthalmic a...
# 25        2579     529665  Neurodevelopmental delay-seizures-ophthalmic a...
# 26        2580     536467  B3GALT6-related spondylodysplastic Ehlers-Danl...
# 27        2581     536467  B3GALT6-related spondylodysplastic Ehlers-Danl...
# 28        2582     536532       Classical-like Ehlers-Danlos syndrome type 2
# 29        2583     536532       Classical-like Ehlers-Danlos syndrome type 2
# 30        2584     541423  Growth delay-intellectual disability-hepatopat...
# 31        2585     541423  Growth delay-intellectual disability-hepatopat...
# 32        2586     542306  GNB5-related intellectual disability-cardiac a...
# 33        2587     542306  GNB5-related intellectual disability-cardiac a...
# 34        2588     542310  Leukoencephalopathy with calcifications and cysts
# 35        2589     542310  Leukoencephalopathy with calcifications and cysts
# 36        2590     544469               PRUNE1-related neurological syndrome
# 37        2591     544469               PRUNE1-related neurological syndrome
# 38        2592     565624  Combined oxidative phosphorylation defect type 39
# 39        2593     565624  Combined oxidative phosphorylation defect type 39
#
#                                               HPO_ALL  \
# 0   HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 1   HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 2   HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 3   HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 4      HP:0012733; HP:0001304; HP:0011509; HP:0007988
# 5      HP:0012733; HP:0001304; HP:0011509; HP:0007988
# 6   HP:0007052; HP:0002071; HP:0001288; HP:0002187...
# 7   HP:0007052; HP:0002071; HP:0001288; HP:0002187...
# 8   HP:0005789; HP:0000365; HP:0000648; HP:0000618...
# 9   HP:0005789; HP:0000365; HP:0000648; HP:0000618...
# 10  HP:0002383; HP:0000826; HP:0000822; HP:0001337...
# 11  HP:0002383; HP:0000826; HP:0000822; HP:0001337...
# 12  HP:0011488; HP:0006756; HP:0002837; HP:0012576...
# 13  HP:0011488; HP:0006756; HP:0002837; HP:0012576...
# 14  HP:0001249; HP:0001250; HP:0004374; HP:0001252...
# 15  HP:0001249; HP:0001250; HP:0004374; HP:0001252...
# 16  HP:0040246; HP:0002638; HP:0001976; HP:0002204...
# 17  HP:0040246; HP:0002638; HP:0001976; HP:0002204...
# 18  HP:0000244; HP:0000444; HP:0001770; HP:0009601...
# 19  HP:0000244; HP:0000444; HP:0001770; HP:0009601...
# 20  HP:0002059; HP:0032097; HP:0001332; HP:0011448...
# 21  HP:0002059; HP:0032097; HP:0001332; HP:0011448...
# 22  HP:0003429; HP:0000571; HP:0002079; HP:0000639...
# 23  HP:0003429; HP:0000571; HP:0002079; HP:0000639...
# 24  HP:0000505; HP:0001272; HP:0000316; HP:0002133...
# 25  HP:0000505; HP:0001272; HP:0000316; HP:0002133...
# 26  HP:0001252; HP:0003414; HP:0002091; HP:0002779...
# 27  HP:0001252; HP:0003414; HP:0002091; HP:0002779...
# 28  HP:0001488; HP:0001270; HP:0006439; HP:0001852...
# 29  HP:0001488; HP:0001270; HP:0006439; HP:0001852...
# 30  HP:0100511; HP:0002719; HP:0006129; HP:0001399...
# 31  HP:0100511; HP:0002719; HP:0006129; HP:0001399...
# 32  HP:0002521; HP:0001344; HP:0000639; HP:0011675...
# 33  HP:0002521; HP:0001344; HP:0000639; HP:0011675...
# 34  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 35  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 36  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 37  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 38  HP:0000028; HP:0011344; HP:0007371; HP:0006956...
# 39  HP:0000028; HP:0011344; HP:0007371; HP:0006956...
#
#                                                 HPO_5  \
# 0   HP:0005619; HP:0009826; HP:0005819; HP:0008905...
# 1   HP:0003498; HP:0000256; HP:0000365; HP:0004060...
# 2   HP:0002014; HP:0011964; HP:0002013; HP:0011387...
# 3   HP:0002014; HP:0001510; HP:0003126; HP:0000128...
# 4      HP:0012733; HP:0007988; HP:0001304; HP:0011509
# 5      HP:0012733; HP:0001304; HP:0007988; HP:0011509
# 6   HP:0009709; HP:0004374; HP:0002828; HP:0001337...
# 7   HP:0000252; HP:0001063; HP:0002071; HP:0009710...
# 8   HP:0002007; HP:0001881; HP:0006824; HP:0009882...
# 9   HP:0005916; HP:0000648; HP:0004322; HP:0002653...
# 10  HP:0002607; HP:0001260; HP:0002376; HP:0001274...
# 11  HP:0002650; HP:0100729; HP:0002167; HP:0000821...
# 12  HP:0001679; HP:0008665; HP:0006756; HP:0000790...
# 13  HP:0011488; HP:0003774; HP:0030034; HP:0002013...
# 14  HP:0001249; HP:0000639; HP:0001263; HP:0000563...
# 15  HP:0000365; HP:0004374; HP:0002084; HP:0006817...
# 16  HP:0030243; HP:0031437; HP:0040246; HP:0004420...
# 17  HP:0040246; HP:0012636; HP:0002625; HP:0002204...
# 18  HP:0100702; HP:0004397; HP:0000505; HP:0000689...
# 19  HP:0001249; HP:0000119; HP:0011380; HP:0000316...
# 20  HP:0001300; HP:0011448; HP:0002059; HP:0002465...
# 21  HP:0002483; HP:0002067; HP:0001263; HP:0011448...
# 22  HP:0001250; HP:0001260; HP:0000639; HP:0000571...
# 23  HP:0001260; HP:0001272; HP:0001263; HP:0002415...
# 24  HP:0000341; HP:0002133; HP:0001256; HP:0000648...
# 25  HP:0000545; HP:0011220; HP:0001337; HP:0000938...
# 26  HP:0100750; HP:0009726; HP:0001357; HP:0011800...
# 27  HP:0001562; HP:0001297; HP:0000703; HP:0002091...
# 28  HP:0001382; HP:0000545; HP:0006480; HP:0001270...
# 29  HP:0000704; HP:0000218; HP:0000465; HP:0010810...
# 30  HP:0000311; HP:0001382; HP:0001562; HP:0002719...
# 31  HP:0031831; HP:0410263; HP:0001382; HP:0001397...
# 32  HP:0001626; HP:0001662; HP:0000639; HP:0000750...
# 33  HP:0001344; HP:0001252; HP:0012248; HP:0002421...
# 34  HP:0001288; HP:0001342; HP:0001268; HP:0002516...
# 35  HP:0001257; HP:0007291; HP:0002461; HP:0001332...
# 36  HP:0000488; HP:0001272; HP:0001639; HP:0012448...
# 37  HP:0000518; HP:0000369; HP:0000252; HP:0001357...
# 38  HP:0000194; HP:0011448; HP:0002058; HP:0009062...
# 39  HP:0003394; HP:0002058; HP:0001998; HP:0001273...
#
#                                             HPO_NOISE
# 0   HP:0005819; HP:0008947; HP:0010536; HP:0010622...
# 1   HP:0008947; HP:0045086; HP:0045087; HP:0003097...
# 2   HP:0002900; HP:0002013; HP:0003126; HP:0031728...
# 3   HP:0001878; HP:0001996; HP:0001508; HP:0004889...
# 4   HP:0012733; HP:0011509; HP:0007988; HP:0100703...
# 5   HP:0001304; HP:0007988; HP:0011509; HP:0008740...
# 6   HP:0005550; HP:0040140; HP:0002139; HP:0100323...
# 7   HP:0002910; HP:0008936; HP:0030880; HP:0010807...
# 8   HP:0000238; HP:0002758; HP:0004322; HP:0033447...
# 9   HP:0001293; HP:0001369; HP:0002757; HP:0031152...
# 10  HP:0001250; HP:0000819; HP:0002353; HP:0031950...
# 11  HP:0000639; HP:0000496; HP:0001260; HP:0031136...
# 12  HP:0000822; HP:0000100; HP:0000092; HP:0001698...
# 13  HP:0000407; HP:0002015; HP:0000790; HP:0012867...
# 14  HP:0006817; HP:0000518; HP:0000639; HP:0008513...
# 15  HP:0000563; HP:0000518; HP:0004374; HP:0011914...
# 16  HP:0040246; HP:0012636; HP:0200067; HP:0012277...
# 17  HP:0002625; HP:0002638; HP:0001976; HP:0005300...
# 18  HP:0000244; HP:0009601; HP:0000689; HP:0030314...
# 19  HP:0000648; HP:0011380; HP:0002983; HP:0005474...
# 20  HP:0011448; HP:0002483; HP:0001337; HP:0025532...
# 21  HP:0100660; HP:0001272; HP:0001337; HP:0003756...
# 22  HP:0003429; HP:0002415; HP:0001007; HP:0002415...
# 23  HP:0001007; HP:0002599; HP:0007256; HP:0012851...
# 24  HP:0001310; HP:0012758; HP:0001347; HP:0002632...
# 25  HP:0000648; HP:0001337; HP:0012758; HP:0033672...
# 26  HP:0002091; HP:0002779; HP:0000218; HP:0100282...
# 27  HP:0012095; HP:0001027; HP:0010575; HP:0031103...
# 28  HP:0000767; HP:0001763; HP:0001822; HP:0006489...
# 29  HP:0025232; HP:0000486; HP:0001166; HP:0025498...
# 30  HP:0001250; HP:0001396; HP:0001249; HP:0000387...
# 31  HP:0001397; HP:0002910; HP:0001249; HP:0011669...
# 32  HP:0000512; HP:0001626; HP:0007010; HP:0031102...
# 33  HP:0001263; HP:0001344; HP:0007010; HP:0001412...
# 34  HP:0100543; HP:0010576; HP:0002059; HP:0100601...
# 35  HP:0007229; HP:0002461; HP:0001257; HP:0005090...
# 36  HP:0032794; HP:0001285; HP:0002313; HP:0033418...
# 37  HP:0008872; HP:0010864; HP:0001272; HP:0010747...
# 38  HP:0009062; HP:0003394; HP:0007321; HP:0031624...
# 39  HP:0001260; HP:0003487; HP:0002650; HP:0025572...

# %%
print(df_pairs_hposet.head(1))
# Out:
#    Unnamed: 0  ORPHACODE         DISEASE  \
# 0           0         15  Achondroplasia
#
#                                              HPO_ALL  \
# 0  HP:0001513; HP:0000463; HP:0011867; HP:0000238...
#
#                                                HPO_5  \
# 0  HP:0005619; HP:0009826; HP:0005819; HP:0008905...
#
#                                            HPO_NOISE
# 0  HP:0005819; HP:0008947; HP:0010536; HP:0010622...

# %%
# Access and print values from the first row for specific columns
hpo_all = df_pairs_hposet.loc[0, 'HPO_ALL']
hpo_5 = df_pairs_hposet.loc[0, 'HPO_5']
hpo_noise = df_pairs_hposet.loc[0, 'HPO_NOISE']

# %%
print(hpo_all)
print(hpo_5)
print(hpo_noise)
# Out:
# HP:0001513; HP:0000463; HP:0011867; HP:0000238; HP:0005819; HP:0003498; HP:0001377; HP:0001156; HP:0005257; HP:0012418; HP:0008445; HP:0002091; HP:0005280; HP:0005619; HP:0003416; HP:0003375; HP:0000956; HP:0010536; HP:0008905; HP:0045086; HP:0002808; HP:0000242; HP:0011452; HP:0000365; HP:0003180; HP:0000260; HP:0008947; HP:0004060; HP:0045087; HP:0002979; HP:0000256; HP:0009826; HP:0003194; HP:0002938; HP:0000309; HP:0002007; HP:0003026; HP:0002870; HP:0010241
# HP:0005619; HP:0009826; HP:0005819; HP:0008905; HP:0001513
# HP:0005819; HP:0008947; HP:0010536; HP:0010622; HP:6000577

# %%
print(hpo_all)
# Out:
# HP:0001513; HP:0000463; HP:0011867; HP:0000238; HP:0005819; HP:0003498; HP:0001377; HP:0001156; HP:0005257; HP:0012418; HP:0008445; HP:0002091; HP:0005280; HP:0005619; HP:0003416; HP:0003375; HP:0000956; HP:0010536; HP:0008905; HP:0045086; HP:0002808; HP:0000242; HP:0011452; HP:0000365; HP:0003180; HP:0000260; HP:0008947; HP:0004060; HP:0045087; HP:0002979; HP:0000256; HP:0009826; HP:0003194; HP:0002938; HP:0000309; HP:0002007; HP:0003026; HP:0002870; HP:0010241

# %%
hpo_all = df_pairs_hposet.loc[2, 'HPO_ALL']
hpo_5 = df_pairs_hposet.loc[2, 'HPO_5']
hpo_noise = df_pairs_hposet.loc[2, 'HPO_NOISE']

# %%
print(hpo_all)
print(hpo_5)
print(hpo_noise)
# Out:
# HP:0000114; HP:0011964; HP:0002013; HP:0004396; HP:0002014; HP:0002653; HP:0004322; HP:0001878; HP:0001996; HP:0001510; HP:0012213; HP:0002659; HP:0003470; HP:0002019; HP:0003109; HP:0001508; HP:0002150; HP:0000121; HP:0002749; HP:0002900; HP:0002747; HP:0000107; HP:0032066; HP:0012405; HP:0003355; HP:0004349; HP:0004918; HP:0012608; HP:0000128; HP:0011387; HP:0000787; HP:0001959; HP:0000407; HP:0003126; HP:0002748; HP:0001944; HP:0001324; HP:0032944
# HP:0002014; HP:0011964; HP:0002013; HP:0011387; HP:0003470
# HP:0002900; HP:0002013; HP:0003126; HP:0031728; HP:0003173
