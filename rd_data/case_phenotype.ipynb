# %%
import pandas as pd
import numpy as np
import random

# %%
# read hpo, orphanet_code and disease information
df = pd.read_csv('hpo_id_orpha.csv')
df
# Out:
#         orphanet_code                                       disease_name  \
# 0                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# 1                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# 2                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# 3                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# 4                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# ...               ...                                                ...
# 114044         658549                 Idiopathic small fibers neuropathy
# 114045         658549                 Idiopathic small fibers neuropathy
# 114046         658549                 Idiopathic small fibers neuropathy
# 114047         658549                 Idiopathic small fibers neuropathy
# 114048         658549                 Idiopathic small fibers neuropathy
#
#             hpo_id
# 0       HP:0001249
# 1       HP:0001939
# 2       HP:0011968
# 3       HP:0000532
# 4       HP:0000533
# ...            ...
# 114044  HP:0007550
# 114045  HP:0008652
# 114046  HP:0002579
# 114047  HP:0032147
# 114048  HP:0012700
#
# [114049 rows x 3 columns]

# %%
# Dropping duplicate rows based on "orphanet_code" and keeping the first occurrence
df = df.drop_duplicates(subset="orphanet_code")
df = df.drop(columns = "hpo_id")
df
# Out:
#         orphanet_code                                       disease_name
# 0                   5  Long chain 3-hydroxyacyl-CoA dehydrogenase def...
# 25                  6        3-methylcrotonyl-CoA carboxylase deficiency
# 35                  7                                        3C syndrome
# 99                  8                                    47,XYY syndrome
# 144                 9                                        Tetrasomy X
# ...               ...                                                ...
# 113858         592574                            Menke-Hennekam syndrome
# 113902         596448                      IgG4-related systemic disease
# 113932         599373                      STXBP1-related encephalopathy
# 113963         647799  MYT1L-related developmental delay-intellectual...
# 114027         658549                 Idiopathic small fibers neuropathy
#
# [4256 rows x 2 columns]

# %%
# read the orphanet code and hpoid of pairs information
df_orpha_hposet = pd.read_csv('case_orphacode_hposet.csv')
df_orpha_hposet
# Out:
#       ORPHACODE                                              HPOID
# 0            15  HP:0000242; HP:0011452; HP:0002979; HP:0000365...
# 1            18  HP:0032066; HP:0012405; HP:0011387; HP:0003355...
# 2            41     HP:0007988; HP:0011509; HP:0001304; HP:0012733
# 3            51  HP:0030038; HP:0000508; HP:0004809; HP:0011834...
# 4            53  HP:0001373; HP:0002758; HP:0002754; HP:0002007...
# ...         ...                                                ...
# 1503     542306  HP:0011704; HP:0000546; HP:0005155; HP:0010864...
# 1504     542310  HP:0010576; HP:0000712; HP:0011153; HP:0001250...
# 1505     544469  HP:0000648; HP:0010864; HP:0002313; HP:0002650...
# 1506     557003  HP:0000278; HP:0000286; HP:0012758; HP:0000519...
# 1507     565624  HP:0001347; HP:0002013; HP:0001260; HP:0002059...
#
# [1508 rows x 2 columns]

# %%
# Merging the data based on the 'ORPHACODE' and 'orphanet_code' columns
df_merged = pd.merge(df_orpha_hposet, df, left_on='ORPHACODE', right_on='orphanet_code', how='inner')

# Display the merged DataFrame
df_merged
# Out:
#       ORPHACODE                                              HPOID  \
# 0            15  HP:0000242; HP:0011452; HP:0002979; HP:0000365...
# 1            18  HP:0032066; HP:0012405; HP:0011387; HP:0003355...
# 2            41     HP:0007988; HP:0011509; HP:0001304; HP:0012733
# 3            51  HP:0030038; HP:0000508; HP:0004809; HP:0011834...
# 4            53  HP:0001373; HP:0002758; HP:0002754; HP:0002007...
# ...         ...                                                ...
# 1503     542306  HP:0011704; HP:0000546; HP:0005155; HP:0010864...
# 1504     542310  HP:0010576; HP:0000712; HP:0011153; HP:0001250...
# 1505     544469  HP:0000648; HP:0010864; HP:0002313; HP:0002650...
# 1506     557003  HP:0000278; HP:0000286; HP:0012758; HP:0000519...
# 1507     565624  HP:0001347; HP:0002013; HP:0001260; HP:0002059...
#
#       orphanet_code                                       disease_name
# 0                15                                     Achondroplasia
# 1                18                      Distal renal tubular acidosis
# 2                41              Dyschromatosis symmetrica hereditaria
# 3                51                         Aicardi-Goutières syndrome
# 4                53                     Albers-Schönberg osteopetrosis
# ...             ...                                                ...
# 1503         542306  GNB5-related intellectual disability-cardiac a...
# 1504         542310  Leukoencephalopathy with calcifications and cysts
# 1505         544469               PRUNE1-related neurological syndrome
# 1506         557003                        Oculoskeletodental syndrome
# 1507         565624  Combined oxidative phosphorylation defect type 39
#
# [1508 rows x 4 columns]

# %%
# Extract the three columns (ORPHACODE', 'disease_name', 'HPOID')
df_case_hposet = df_merged[['ORPHACODE', 'disease_name', 'HPOID']]
print(df_case_hposet.head())
# Out:
#    ORPHACODE                           disease_name  \
# 0         15                         Achondroplasia
# 1         18          Distal renal tubular acidosis
# 2         41  Dyschromatosis symmetrica hereditaria
# 3         51             Aicardi-Goutières syndrome
# 4         53         Albers-Schönberg osteopetrosis
#
#                                                HPOID
# 0  HP:0000242; HP:0011452; HP:0002979; HP:0000365...
# 1  HP:0032066; HP:0012405; HP:0011387; HP:0003355...
# 2     HP:0007988; HP:0011509; HP:0001304; HP:0012733
# 3  HP:0030038; HP:0000508; HP:0004809; HP:0011834...
# 4  HP:0001373; HP:0002758; HP:0002754; HP:0002007...

# %%
df_case_hposet = df_case_hposet.rename(columns={"disease_name": "DISEASE"})
df_case_hposet = df_case_hposet.rename(columns={"HPOID": "HPO_ALL"})
df_case_hposet
# Out:
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 1            18                      Distal renal tubular acidosis
# 2            41              Dyschromatosis symmetrica hereditaria
# 3            51                         Aicardi-Goutières syndrome
# 4            53                     Albers-Schönberg osteopetrosis
# ...         ...                                                ...
# 1503     542306  GNB5-related intellectual disability-cardiac a...
# 1504     542310  Leukoencephalopathy with calcifications and cysts
# 1505     544469               PRUNE1-related neurological syndrome
# 1506     557003                        Oculoskeletodental syndrome
# 1507     565624  Combined oxidative phosphorylation defect type 39
#
#                                                 HPO_ALL
# 0     HP:0000242; HP:0011452; HP:0002979; HP:0000365...
# 1     HP:0032066; HP:0012405; HP:0011387; HP:0003355...
# 2        HP:0007988; HP:0011509; HP:0001304; HP:0012733
# 3     HP:0030038; HP:0000508; HP:0004809; HP:0011834...
# 4     HP:0001373; HP:0002758; HP:0002754; HP:0002007...
# ...                                                 ...
# 1503  HP:0011704; HP:0000546; HP:0005155; HP:0010864...
# 1504  HP:0010576; HP:0000712; HP:0011153; HP:0001250...
# 1505  HP:0000648; HP:0010864; HP:0002313; HP:0002650...
# 1506  HP:0000278; HP:0000286; HP:0012758; HP:0000519...
# 1507  HP:0001347; HP:0002013; HP:0001260; HP:0002059...
#
# [1508 rows x 3 columns]

# %%
# Extract the first two columns (ORPHACODE, DISEASE)
df_orpha_disease = df_case_hposet[['ORPHACODE', 'DISEASE']]
# Save to a csv file
df_orpha_disease.to_csv("case_orphacode_disease.csv", index=False)

# %%
df_case_hposet
# Out:
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 1            18                      Distal renal tubular acidosis
# 2            41              Dyschromatosis symmetrica hereditaria
# 3            51                         Aicardi-Goutières syndrome
# 4            53                     Albers-Schönberg osteopetrosis
# ...         ...                                                ...
# 1503     542306  GNB5-related intellectual disability-cardiac a...
# 1504     542310  Leukoencephalopathy with calcifications and cysts
# 1505     544469               PRUNE1-related neurological syndrome
# 1506     557003                        Oculoskeletodental syndrome
# 1507     565624  Combined oxidative phosphorylation defect type 39
#
#                                                 HPO_ALL
# 0     HP:0000242; HP:0011452; HP:0002979; HP:0000365...
# 1     HP:0032066; HP:0012405; HP:0011387; HP:0003355...
# 2        HP:0007988; HP:0011509; HP:0001304; HP:0012733
# 3     HP:0030038; HP:0000508; HP:0004809; HP:0011834...
# 4     HP:0001373; HP:0002758; HP:0002754; HP:0002007...
# ...                                                 ...
# 1503  HP:0011704; HP:0000546; HP:0005155; HP:0010864...
# 1504  HP:0010576; HP:0000712; HP:0011153; HP:0001250...
# 1505  HP:0000648; HP:0010864; HP:0002313; HP:0002650...
# 1506  HP:0000278; HP:0000286; HP:0012758; HP:0000519...
# 1507  HP:0001347; HP:0002013; HP:0001260; HP:0002059...
#
# [1508 rows x 3 columns]

# %%
# Save to a csv file
df_case_hposet.to_csv("case_orphacode_hposet.csv", index=False)

# %%
# Define the function with file-saving capability
def case_phenotypes(n, m):
    
    # Read the file into a DataFrame, assuming it is tab-separated
    df = pd.read_csv('case_orphacode_hposet.csv')
    
    # Ensure n and m are within the specified limits
    n = min(n, 814)
    m = min(m, 694)
    
    # Extract first n rows and last m rows
    rows_extracted = pd.concat([df.head(n), df.tail(m)])
    
    # Save the result to a txt file
    rows_extracted.to_csv('case_phenotypes.csv', index=False)
    
    return rows_extracted

# %%
df_case_phenotypes = case_phenotypes(n=20, m=20)
print(df_case_phenotypes)
# Out:
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 1            18                      Distal renal tubular acidosis
# 2            41              Dyschromatosis symmetrica hereditaria
# 3            51                         Aicardi-Goutières syndrome
# 4            53                     Albers-Schönberg osteopetrosis
# 5            58                                  Alexander disease
# 6            63                                    Alport syndrome
# 7            65                         Leber congenital amaurosis
# 8            82  Hereditary thrombophilia due to congenital ant...
# 9            87                                     Apert syndrome
# 10           97                         Familial paroxysmal ataxia
# 11          107                                       BOR syndrome
# 12          112                                   Bartter syndrome
# 13          115             Congenital contractural arachnodactyly
# 14          116                        Beckwith-Wiedemann syndrome
# 15          122                            Birt-Hogg-Dubé syndrome
# 16          124                            Diamond-Blackfan anemia
# 17          126  Blepharophimosis-ptosis-epicanthus inversus sy...
# 18          130                                   Brugada syndrome
# 19          136  Cerebral autosomal dominant arteriopathy-subco...
# 1488     480536  MSH3-related attenuated familial adenomatous p...
# 1489     488642  TELO2-related intellectual disability-neurodev...
# 1490     496641  Early-onset progressive diffuse brain atrophy-...
# 1491     500144  Early-onset progressive encephalopathy-hearing...
# 1492     500533  Polyhydramnios-megalencephaly-symptomatic epil...
# 1493     504476  Cerebellar ataxia with neuropathy and bilatera...
# 1494     505216                 3-methylglutaconic aciduria type 9
# 1495     508093                                     MEPAN syndrome
# 1496     513436     Autosomal recessive spastic paraplegia type 78
# 1497     521406   Dystonia-parkinsonism-hypermanganesemia syndrome
# 1498     527497  NKX6-2-related autosomal recessive hypomyelina...
# 1499     529665  Neurodevelopmental delay-seizures-ophthalmic a...
# 1500     536467  B3GALT6-related spondylodysplastic Ehlers-Danl...
# 1501     536532       Classical-like Ehlers-Danlos syndrome type 2
# 1502     541423  Growth delay-intellectual disability-hepatopat...
# 1503     542306  GNB5-related intellectual disability-cardiac a...
# 1504     542310  Leukoencephalopathy with calcifications and cysts
# 1505     544469               PRUNE1-related neurological syndrome
# 1506     557003                        Oculoskeletodental syndrome
# 1507     565624  Combined oxidative phosphorylation defect type 39
#
#                                                 HPO_ALL
# 0     HP:0000242; HP:0011452; HP:0002979; HP:0000365...
# 1     HP:0032066; HP:0012405; HP:0011387; HP:0003355...
# 2        HP:0007988; HP:0011509; HP:0001304; HP:0012733
# 3     HP:0030038; HP:0000508; HP:0004809; HP:0011834...
# 4     HP:0001373; HP:0002758; HP:0002754; HP:0002007...
# 5     HP:0001251; HP:0000639; HP:0002093; HP:0000470...
# 6     HP:0008665; HP:0000093; HP:0000794; HP:0012735...
# 7     HP:0012795; HP:0001263; HP:0000563; HP:0000518...
# 8     HP:0005305; HP:0002625; HP:0030243; HP:0012636...
# 9     HP:0000822; HP:0008872; HP:0002119; HP:0000316...
# 10    HP:0000651; HP:0006855; HP:0001251; HP:0000639...
# 11    HP:0000359; HP:0000370; HP:0000356; HP:0004467...
# 12                               HP:0004322; HP:0001939
# 13    HP:0001166; HP:0001533; HP:0001387; HP:0000218...
# 14    HP:0012758; HP:0010535; HP:0000239; HP:0001998...
# 15    HP:0100632; HP:0002865; HP:0002097; HP:0001012...
# 16    HP:0008551; HP:0001631; HP:0000085; HP:0000185...
# 17    HP:0000508; HP:0000286; HP:0011481; HP:0000639...
# 18    HP:0001279; HP:0011715; HP:0004308; HP:0011705...
# 19    HP:0001289; HP:0010992; HP:0001250; HP:0001297...
# 1488  HP:0100743; HP:0025274; HP:0012740; HP:0008069...
# 1489  HP:0000081; HP:0006380; HP:0002751; HP:0008513...
# 1490  HP:0008947; HP:0001344; HP:0002079; HP:0001257...
# 1491  HP:0001338; HP:0002120; HP:0000011; HP:0002020...
# 1492  HP:0000348; HP:0001344; HP:0001631; HP:0030891...
# 1493  HP:0002460; HP:0000750; HP:0002073; HP:0002080...
# 1494  HP:0001347; HP:0001250; HP:0001298; HP:0001324...
# 1495  HP:0012179; HP:0001336; HP:0002015; HP:0000639...
# 1496  HP:0003477; HP:0100543; HP:0000317; HP:0003487...
# 1497  HP:0002505; HP:0002650; HP:0002828; HP:0030890...
# 1498  HP:0007704; HP:0002415; HP:0001007; HP:0001272...
# 1499  HP:0001250; HP:0002066; HP:0001257; HP:0003155...
# 1500  HP:0000463; HP:0001762; HP:0004568; HP:0003300...
# 1501  HP:0025509; HP:0001763; HP:0000189; HP:0000767...
# 1502  HP:0410263; HP:0011968; HP:0031831; HP:0001510...
# 1503  HP:0011704; HP:0000546; HP:0005155; HP:0010864...
# 1504  HP:0010576; HP:0000712; HP:0011153; HP:0001250...
# 1505  HP:0000648; HP:0010864; HP:0002313; HP:0002650...
# 1506  HP:0000278; HP:0000286; HP:0012758; HP:0000519...
# 1507  HP:0001347; HP:0002013; HP:0001260; HP:0002059...

# %%
# Function to randomly select n HPO terms from the HPOALL column in df_pairs_hposet
def case_hpo(i, n, m):
    
    # read the orphanet code and hpoid of pairs information
    df_case_hposet = pd.read_csv('case_phenotypes.csv')
    
    def random_hpo(hpo_str, i):
        # Split the HPO terms by "; " and randomly select n terms
        hpo_terms = hpo_str.split("; ")
        selected_terms = random.sample(hpo_terms, min(i, len(hpo_terms)))  # limit to available terms
        return "; ".join(selected_terms)
    
    # Function to select random HPO terms from a string
    def random_hpo_noise(hpo_str, num_terms):
        # Split the HPO terms by "; " and randomly select the specified number of terms
        hpo_terms = hpo_str.split("; ")
        selected_terms = random.sample(hpo_terms, min(num_terms, len(hpo_terms)))  # limit to available terms
        return selected_terms
   
    # read all the hpo term
    df_all_hpo = pd.read_csv('hpo_id_all.csv')
    
    # Convert df_all_hpo 'hpo_id' column to a list of all HPO terms
    all_hpo_terms = df_all_hpo['hpo_id'].tolist()
    
    # Apply the function to create the HPO_NOISE column in df_pairs_hposet
    def combine_hpo_noise(row):
        # Select n terms from the HPO_ALL column in df_pairs_hposet
        selected_hpo_all = random_hpo_noise(row['HPO_ALL'], n)
        # Select m terms from the df_all_hpo HPO list
        selected_hpo_noise = random.sample(all_hpo_terms, min(m, len(all_hpo_terms)))
        # Combine and return as a single string with "; " delimiter
        return "; ".join(selected_hpo_all + selected_hpo_noise)

    # Apply the function to each row in df_pairs_hposet
    df_case_hposet[f'HPO_{i}'] = df_pairs_hposet['HPO_ALL'].apply(lambda x: random_hpo(x, i))    

    # Add the new column HPO_NOISE to df_pairs_hposet
    df_case_hposet['HPO_NOISE'] = df_pairs_hposet.apply(combine_hpo_noise, axis=1)
    
    # Save the result to a csv file
    df_case_hposet.to_csv('pairs_hpo.csv')

    return df_case_hposet

# %%
# Example usage (assuming df_pairs_hposet and df_all_hpo are defined):
df_case_hposet = case_hpo(i=5, n=3, m=2)
print(df_case_hposet)
# Out:
#     ORPHACODE                                            DISEASE  \
# 0          15                                     Achondroplasia
# 1          18                      Distal renal tubular acidosis
# 2          41              Dyschromatosis symmetrica hereditaria
# 3          51                         Aicardi-Goutières syndrome
# 4          53                     Albers-Schönberg osteopetrosis
# 5          58                                  Alexander disease
# 6          63                                    Alport syndrome
# 7          65                         Leber congenital amaurosis
# 8          82  Hereditary thrombophilia due to congenital ant...
# 9          87                                     Apert syndrome
# 10         97                         Familial paroxysmal ataxia
# 11        107                                       BOR syndrome
# 12        112                                   Bartter syndrome
# 13        115             Congenital contractural arachnodactyly
# 14        116                        Beckwith-Wiedemann syndrome
# 15        122                            Birt-Hogg-Dubé syndrome
# 16        124                            Diamond-Blackfan anemia
# 17        126  Blepharophimosis-ptosis-epicanthus inversus sy...
# 18        130                                   Brugada syndrome
# 19        136  Cerebral autosomal dominant arteriopathy-subco...
# 20     480536  MSH3-related attenuated familial adenomatous p...
# 21     488642  TELO2-related intellectual disability-neurodev...
# 22     496641  Early-onset progressive diffuse brain atrophy-...
# 23     500144  Early-onset progressive encephalopathy-hearing...
# 24     500533  Polyhydramnios-megalencephaly-symptomatic epil...
# 25     504476  Cerebellar ataxia with neuropathy and bilatera...
# 26     505216                 3-methylglutaconic aciduria type 9
# 27     508093                                     MEPAN syndrome
# 28     513436     Autosomal recessive spastic paraplegia type 78
# 29     521406   Dystonia-parkinsonism-hypermanganesemia syndrome
# 30     527497  NKX6-2-related autosomal recessive hypomyelina...
# 31     529665  Neurodevelopmental delay-seizures-ophthalmic a...
# 32     536467  B3GALT6-related spondylodysplastic Ehlers-Danl...
# 33     536532       Classical-like Ehlers-Danlos syndrome type 2
# 34     541423  Growth delay-intellectual disability-hepatopat...
# 35     542306  GNB5-related intellectual disability-cardiac a...
# 36     542310  Leukoencephalopathy with calcifications and cysts
# 37     544469               PRUNE1-related neurological syndrome
# 38     557003                        Oculoskeletodental syndrome
# 39     565624  Combined oxidative phosphorylation defect type 39
#
#                                               HPO_ALL  \
# 0   HP:0000242; HP:0011452; HP:0002979; HP:0000365...
# 1   HP:0032066; HP:0012405; HP:0011387; HP:0003355...
# 2      HP:0007988; HP:0011509; HP:0001304; HP:0012733
# 3   HP:0030038; HP:0000508; HP:0004809; HP:0011834...
# 4   HP:0001373; HP:0002758; HP:0002754; HP:0002007...
# 5   HP:0001251; HP:0000639; HP:0002093; HP:0000470...
# 6   HP:0008665; HP:0000093; HP:0000794; HP:0012735...
# 7   HP:0012795; HP:0001263; HP:0000563; HP:0000518...
# 8   HP:0005305; HP:0002625; HP:0030243; HP:0012636...
# 9   HP:0000822; HP:0008872; HP:0002119; HP:0000316...
# 10  HP:0000651; HP:0006855; HP:0001251; HP:0000639...
# 11  HP:0000359; HP:0000370; HP:0000356; HP:0004467...
# 12                             HP:0004322; HP:0001939
# 13  HP:0001166; HP:0001533; HP:0001387; HP:0000218...
# 14  HP:0012758; HP:0010535; HP:0000239; HP:0001998...
# 15  HP:0100632; HP:0002865; HP:0002097; HP:0001012...
# 16  HP:0008551; HP:0001631; HP:0000085; HP:0000185...
# 17  HP:0000508; HP:0000286; HP:0011481; HP:0000639...
# 18  HP:0001279; HP:0011715; HP:0004308; HP:0011705...
# 19  HP:0001289; HP:0010992; HP:0001250; HP:0001297...
# 20  HP:0100743; HP:0025274; HP:0012740; HP:0008069...
# 21  HP:0000081; HP:0006380; HP:0002751; HP:0008513...
# 22  HP:0008947; HP:0001344; HP:0002079; HP:0001257...
# 23  HP:0001338; HP:0002120; HP:0000011; HP:0002020...
# 24  HP:0000348; HP:0001344; HP:0001631; HP:0030891...
# 25  HP:0002460; HP:0000750; HP:0002073; HP:0002080...
# 26  HP:0001347; HP:0001250; HP:0001298; HP:0001324...
# 27  HP:0012179; HP:0001336; HP:0002015; HP:0000639...
# 28  HP:0003477; HP:0100543; HP:0000317; HP:0003487...
# 29  HP:0002505; HP:0002650; HP:0002828; HP:0030890...
# 30  HP:0007704; HP:0002415; HP:0001007; HP:0001272...
# 31  HP:0001250; HP:0002066; HP:0001257; HP:0003155...
# 32  HP:0000463; HP:0001762; HP:0004568; HP:0003300...
# 33  HP:0025509; HP:0001763; HP:0000189; HP:0000767...
# 34  HP:0410263; HP:0011968; HP:0031831; HP:0001510...
# 35  HP:0011704; HP:0000546; HP:0005155; HP:0010864...
# 36  HP:0010576; HP:0000712; HP:0011153; HP:0001250...
# 37  HP:0000648; HP:0010864; HP:0002313; HP:0002650...
# 38  HP:0000278; HP:0000286; HP:0012758; HP:0000519...
# 39  HP:0001347; HP:0002013; HP:0001260; HP:0002059...
#
#                                                 HPO_5  \
# 0   HP:0010241; HP:0000256; HP:0001377; HP:0005619...
# 1   HP:0045087; HP:0000238; HP:0000463; HP:0002091...
# 2   HP:0012213; HP:0000128; HP:0000787; HP:0000407...
# 3   HP:0001878; HP:0000114; HP:0032944; HP:0003126...
# 4      HP:0007988; HP:0011509; HP:0001304; HP:0012733
# 5      HP:0007988; HP:0012733; HP:0011509; HP:0001304
# 6   HP:0001639; HP:0040140; HP:0100614; HP:0000252...
# 7   HP:0009704; HP:0001433; HP:0000821; HP:0000819...
# 8   HP:0000505; HP:0001903; HP:0002754; HP:0002757...
# 9   HP:0001373; HP:0004322; HP:0005789; HP:0000256...
# 10  HP:0007256; HP:0001251; HP:0001250; HP:0001324...
# 11  HP:0001645; HP:0001347; HP:0000238; HP:0002360...
# 12  HP:0000822; HP:0410019; HP:0012576; HP:0012735...
# 13  HP:0003774; HP:0000083; HP:0012577; HP:0002094...
# 14  HP:0000563; HP:0012795; HP:0002269; HP:0001263...
# 15  HP:0002084; HP:0000512; HP:0000365; HP:0000639...
# 16  HP:0001976; HP:0030248; HP:0030242; HP:0002204...
# 17  HP:0031437; HP:0002638; HP:0012636; HP:0040246...
# 18  HP:0000689; HP:0000975; HP:0002308; HP:0000407...
# 19  HP:0000586; HP:0004397; HP:0012368; HP:0000453...
# 20  HP:0000639; HP:0000473; HP:0001251; HP:0000651...
# 21  HP:0002017; HP:0001249; HP:0000639; HP:0000360...
# 22  HP:0000074; HP:0000324; HP:0011388; HP:0008678...
# 23  HP:0007925; HP:0000278; HP:0011387; HP:0000003...
# 24                             HP:0004322; HP:0001939
# 25                             HP:0004322; HP:0001939
# 26  HP:0003011; HP:0001634; HP:0001371; HP:0001166...
# 27  HP:0001371; HP:0001387; HP:0002650; HP:0002575...
# 28  HP:0002167; HP:0005616; HP:0005487; HP:0000520...
# 29  HP:0000121; HP:0000028; HP:0005487; HP:0001139...
# 30  HP:0002097; HP:0007703; HP:0100632; HP:0005584...
# 31  HP:0002097; HP:0200034; HP:0010609; HP:0002865...
# 32  HP:0008551; HP:0002669; HP:0000185; HP:0000369...
# 33  HP:0000085; HP:0000347; HP:0001873; HP:0002817...
# 34  HP:0000508; HP:0000581; HP:0011481; HP:0000286...
# 35  HP:0011481; HP:0000639; HP:0005280; HP:0000581...
# 36  HP:0001663; HP:0012251; HP:0004751; HP:0001649...
# 37  HP:0004751; HP:0012251; HP:0011712; HP:0011705...
# 38  HP:0002352; HP:0001300; HP:0000726; HP:0001250...
# 39  HP:0002076; HP:0001297; HP:0000739; HP:0001289...
#
#                                             HPO_NOISE
# 0   HP:0003416; HP:0008445; HP:0005280; HP:0100530...
# 1   HP:0000260; HP:0009826; HP:0001513; HP:0005191...
# 2   HP:0004322; HP:0001878; HP:0002747; HP:0010519...
# 3   HP:0003126; HP:0011387; HP:0000787; HP:0030218...
# 4   HP:0001304; HP:0011509; HP:0007988; HP:0009102...
# 5   HP:0001304; HP:0011509; HP:0007988; HP:0031555...
# 6   HP:0001250; HP:0011834; HP:0002119; HP:0012221...
# 7   HP:0002187; HP:0001288; HP:0002313; HP:0000499...
# 8   HP:0010885; HP:0000505; HP:0002007; HP:0002790...
# 9   HP:0004322; HP:0002857; HP:0000944; HP:0100810...
# 10  HP:0002169; HP:0000712; HP:0001250; HP:0040019...
# 11  HP:0002019; HP:0001260; HP:0100716; HP:0011433...
# 12  HP:0025005; HP:0000822; HP:0000083; HP:0002944...
# 13  HP:0003774; HP:0000790; HP:0025005; HP:0007813...
# 14  HP:0000512; HP:0001263; HP:0007703; HP:0007024...
# 15  HP:0007703; HP:0001141; HP:0000518; HP:0001849...
# 16  HP:0200067; HP:0030242; HP:0030248; HP:0010926...
# 17  HP:0030248; HP:0200067; HP:0005268; HP:0001260...
# 18  HP:0009601; HP:0000494; HP:0000486; HP:0003450...
# 19  HP:0000244; HP:0002308; HP:0004635; HP:0100674...
# 20  HP:0006855; HP:0002321; HP:0002017; HP:0008489...
# 21  HP:0001249; HP:0002017; HP:0000639; HP:0007988...
# 22  HP:0000324; HP:0011481; HP:0000413; HP:0034029...
# 23  HP:0000405; HP:0008586; HP:0011387; HP:0011880...
# 24     HP:0004322; HP:0001939; HP:0025195; HP:0012047
# 25     HP:0001939; HP:0004322; HP:0001096; HP:0030588
# 26  HP:0001166; HP:0002575; HP:0001533; HP:0007328...
# 27  HP:0004942; HP:0030680; HP:0002566; HP:4000210...
# 28  HP:0002664; HP:0001520; HP:0000821; HP:0006114...
# 29  HP:0000776; HP:0002664; HP:0005562; HP:0003075...
# 30  HP:0010609; HP:0002107; HP:0002897; HP:0012642...
# 31  HP:0002897; HP:0002097; HP:0010609; HP:0032156...
# 32  HP:0001510; HP:0012410; HP:0030270; HP:0031088...
# 33  HP:0005280; HP:0001896; HP:0001895; HP:0011379...
# 34  HP:0011481; HP:0000581; HP:0005280; HP:0004679...
# 35  HP:0000664; HP:0000639; HP:0000486; HP:0011736...
# 36  HP:0011715; HP:0001695; HP:0004755; HP:0011482...
# 37  HP:0001695; HP:0001279; HP:0004751; HP:0012650...
# 38  HP:0002463; HP:0010794; HP:0002301; HP:0002644...
# 39  HP:0002500; HP:0001260; HP:0002354; HP:0002339...

# %%
print(df_case_hposet.head(1))
# Out:
#    ORPHACODE         DISEASE  \
# 0         15  Achondroplasia
#
#                                              HPO_ALL  \
# 0  HP:0000242; HP:0011452; HP:0002979; HP:0000365...
#
#                                                HPO_5  \
# 0  HP:0010241; HP:0000256; HP:0001377; HP:0005619...
#
#                                            HPO_NOISE
# 0  HP:0003416; HP:0008445; HP:0005280; HP:0100530...

# %%
# Access and print values from the first row for specific columns
hpo_all = df_case_hposet.loc[0, 'HPO_ALL']
hpo_5 = df_case_hposet.loc[0, 'HPO_5']
hpo_noise = df_case_hposet.loc[0, 'HPO_NOISE']

# %%
print(hpo_all)
print(hpo_5)
print(hpo_noise)
# Out:
# HP:0000242; HP:0011452; HP:0002979; HP:0000365; HP:0003180; HP:0000260; HP:0008947; HP:0004060; HP:0045087; HP:0010241; HP:0000256; HP:0009826; HP:0003194; HP:0002938; HP:0000309; HP:0002007; HP:0003026; HP:0002870; HP:0002808; HP:0045086; HP:0008905; HP:0000956; HP:0001513; HP:0011867; HP:0000238; HP:0005819; HP:0003498; HP:0001377; HP:0000463; HP:0001156; HP:0010536; HP:0012418; HP:0008445; HP:0002091; HP:0005280; HP:0005619; HP:0003416; HP:0005257; HP:0003375
# HP:0010241; HP:0000256; HP:0001377; HP:0005619; HP:0000238
# HP:0003416; HP:0008445; HP:0005280; HP:0100530; HP:0031983

# %%
print(hpo_all)
# Out:
# HP:0000242; HP:0011452; HP:0002979; HP:0000365; HP:0003180; HP:0000260; HP:0008947; HP:0004060; HP:0045087; HP:0010241; HP:0000256; HP:0009826; HP:0003194; HP:0002938; HP:0000309; HP:0002007; HP:0003026; HP:0002870; HP:0002808; HP:0045086; HP:0008905; HP:0000956; HP:0001513; HP:0011867; HP:0000238; HP:0005819; HP:0003498; HP:0001377; HP:0000463; HP:0001156; HP:0010536; HP:0012418; HP:0008445; HP:0002091; HP:0005280; HP:0005619; HP:0003416; HP:0005257; HP:0003375

# %%
hpo_all = df_case_hposet.loc[2, 'HPO_ALL']
hpo_5 = df_case_hposet.loc[2, 'HPO_5']
hpo_noise = df_case_hposet.loc[2, 'HPO_NOISE']

# %%
print(hpo_all)
print(hpo_5)
print(hpo_noise)
# Out:
# HP:0000114; HP:0011964; HP:0002013; HP:0004396; HP:0002014; HP:0002653; HP:0004322; HP:0001878; HP:0001996; HP:0001510; HP:0012213; HP:0002659; HP:0003470; HP:0002019; HP:0003109; HP:0001508; HP:0002150; HP:0000121; HP:0002749; HP:0002900; HP:0002747; HP:0000107; HP:0032066; HP:0012405; HP:0003355; HP:0004349; HP:0004918; HP:0012608; HP:0000128; HP:0011387; HP:0000787; HP:0001959; HP:0000407; HP:0003126; HP:0002748; HP:0001944; HP:0001324; HP:0032944
# HP:0002014; HP:0011964; HP:0002013; HP:0011387; HP:0003470
# HP:0002900; HP:0002013; HP:0003126; HP:0031728; HP:0003173
