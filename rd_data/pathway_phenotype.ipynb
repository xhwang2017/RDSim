# %%
import pandas as pd
import numpy as np
import random

# %%
# read the orphanet code and hpoid of samples information
df_orpha_hposet = pd.read_csv('pathway_orphacode_hposet.csv')
df_orpha_hposet
# Out:
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 1            15                                     Achondroplasia
# 2            15                                     Achondroplasia
# 3            18                      Distal renal tubular acidosis
# 4            18                      Distal renal tubular acidosis
# ...         ...                                                ...
# 2203     542310  Leukoencephalopathy with calcifications and cysts
# 2204     542310  Leukoencephalopathy with calcifications and cysts
# 2205     544469               PRUNE1-related neurological syndrome
# 2206     544469               PRUNE1-related neurological syndrome
# 2207     544469               PRUNE1-related neurological syndrome
#
#                                                 HPO_ALL
# 0     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 1     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 2     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 3     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 4     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# ...                                                 ...
# 2203  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2204  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2205  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2206  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2207  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
#
# [2208 rows x 3 columns]

# %%
unique_df = df_orpha_hposet.drop_duplicates()
unique_df
# Out:
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 3            18                      Distal renal tubular acidosis
# 6            41              Dyschromatosis symmetrica hereditaria
# 9            51                         Aicardi-Goutières syndrome
# 12           63                                    Alport syndrome
# ...         ...                                                ...
# 2193     536467  B3GALT6-related spondylodysplastic Ehlers-Danl...
# 2196     541423  Growth delay-intellectual disability-hepatopat...
# 2199     542306  GNB5-related intellectual disability-cardiac a...
# 2202     542310  Leukoencephalopathy with calcifications and cysts
# 2205     544469               PRUNE1-related neurological syndrome
#
#                                                 HPO_ALL
# 0     HP:0001513; HP:0000463; HP:0011867; HP:0000238...
# 3     HP:0000114; HP:0011964; HP:0002013; HP:0004396...
# 6        HP:0012733; HP:0001304; HP:0011509; HP:0007988
# 9     HP:0007052; HP:0002071; HP:0001288; HP:0002187...
# 12    HP:0011488; HP:0006756; HP:0002837; HP:0012576...
# ...                                                 ...
# 2193  HP:0001252; HP:0003414; HP:0002091; HP:0002779...
# 2196  HP:0100511; HP:0002719; HP:0006129; HP:0001399...
# 2199  HP:0002521; HP:0001344; HP:0000639; HP:0011675...
# 2202  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2205  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
#
# [736 rows x 3 columns]

# %%
# Extract the first two columns (ORPHACODE, DISEASE)
df_orpha_disease = unique_df[['ORPHACODE', 'DISEASE']]

# Save to a csv file
df_orpha_disease.to_csv("pathway_orphacode_disease.csv", index=False)

# %%
# Define the function with file-saving capability
def pathway_phenotypes(n, m):
    
    # Read the file into a DataFrame, assuming it is tab-separated
    df = pd.read_csv('pathway_orphacode_hposet.csv')
    
    # Ensure n and m are within the specified limits
    n = min(n, 1026)
    m = min(m, 1182)
    
    # Extract first n rows and last m rows
    rows_extracted = pd.concat([df.head(n), df.tail(m)])
    
    # Save the result to a txt file
    rows_extracted.to_csv('pathway_phenotypes.csv', index=False)
    
    return rows_extracted

# %%
df_pathway_phenotypes = pathway_phenotypes(n=30, m=30)
print(df_pathway_phenotypes)
# Out:
#       ORPHACODE                                            DISEASE  \
# 0            15                                     Achondroplasia
# 1            15                                     Achondroplasia
# 2            15                                     Achondroplasia
# 3            18                      Distal renal tubular acidosis
# 4            18                      Distal renal tubular acidosis
# 5            18                      Distal renal tubular acidosis
# 6            41              Dyschromatosis symmetrica hereditaria
# 7            41              Dyschromatosis symmetrica hereditaria
# 19    HP:0040246; HP:0002638; HP:0001976; HP:0002204...
# 20    HP:0040246; HP:0002638; HP:0001976; HP:0002204...
# 21    HP:0000244; HP:0000444; HP:0001770; HP:0009601...
# 22    HP:0000244; HP:0000444; HP:0001770; HP:0009601...
# 23    HP:0000244; HP:0000444; HP:0001770; HP:0009601...
# 24    HP:0002076; HP:0002321; HP:0001260; HP:0002301...
# 25    HP:0002076; HP:0002321; HP:0001260; HP:0002301...
# 26    HP:0002076; HP:0002321; HP:0001260; HP:0002301...
# 27    HP:0000413; HP:0011388; HP:0008586; HP:0011395...
# 28    HP:0000413; HP:0011388; HP:0008586; HP:0011395...
# 29    HP:0000413; HP:0011388; HP:0008586; HP:0011395...
# 2178  HP:0004394; HP:0200063; HP:0000131; HP:0000854...
# 2179  HP:0004394; HP:0200063; HP:0000131; HP:0000854...
# 2180  HP:0004394; HP:0200063; HP:0000131; HP:0000854...
# 2181  HP:0001263; HP:0001561; HP:0011968; HP:0001355...
# 2182  HP:0001263; HP:0001561; HP:0011968; HP:0001355...
# 2183  HP:0001263; HP:0001561; HP:0011968; HP:0001355...
# 2184  HP:0000407; HP:0001260; HP:0002075; HP:0002066...
# 2185  HP:0000407; HP:0001260; HP:0002075; HP:0002066...
# 2186  HP:0000407; HP:0001260; HP:0002075; HP:0002066...
# 2187  HP:0002059; HP:0032097; HP:0001332; HP:0011448...
# 2188  HP:0002059; HP:0032097; HP:0001332; HP:0011448...
# 2189  HP:0002059; HP:0032097; HP:0001332; HP:0011448...
# 2190  HP:0000505; HP:0001272; HP:0000316; HP:0002133...
# 2191  HP:0000505; HP:0001272; HP:0000316; HP:0002133...
# 2192  HP:0000505; HP:0001272; HP:0000316; HP:0002133...
# 2193  HP:0001252; HP:0003414; HP:0002091; HP:0002779...
# 2194  HP:0001252; HP:0003414; HP:0002091; HP:0002779...
# 2195  HP:0001252; HP:0003414; HP:0002091; HP:0002779...
# 2196  HP:0100511; HP:0002719; HP:0006129; HP:0001399...
# 2197  HP:0100511; HP:0002719; HP:0006129; HP:0001399...
# 2198  HP:0100511; HP:0002719; HP:0006129; HP:0001399...
# 2199  HP:0002521; HP:0001344; HP:0000639; HP:0011675...
# 2200  HP:0002521; HP:0001344; HP:0000639; HP:0011675...
# 2201  HP:0002521; HP:0001344; HP:0000639; HP:0011675...
# 2202  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2203  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2204  HP:0100320; HP:0100543; HP:0001260; HP:0002516...
# 2205  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2206  HP:0002540; HP:0000347; HP:0001285; HP:0001639...
# 2207  HP:0002540; HP:0000347; HP:0001285; HP:0001639...

# %%
# Function to randomly select n HPO terms from the HPOALL column in df_pathway_hposet
def pathway_hpo(i, n, m):
    
    # read the orphanet code and hpoid of samples information
    df_pathway_hposet = pd.read_csv('pathway_phenotypes.csv')
    
    def random_hpo(hpo_str, i):
        # Split the HPO terms by "; " and randomly select n terms
        hpo_terms = hpo_str.split("; ")
        selected_terms = random.sample(hpo_terms, min(i, len(hpo_terms)))  # limit to available terms
        return "; ".join(selected_terms)
    
    # Function to select random HPO terms from a string
    def random_hpo_noise(hpo_str, num_terms):
        # Split the HPO terms by "; " and randomly select the specified number of terms
        hpo_terms = hpo_str.split("; ")
        selected_terms = random.sample(hpo_terms, min(num_terms, len(hpo_terms)))  # limit to available terms
        return selected_terms
   
    # read all the hpo term
    df_all_hpo = pd.read_csv('hpo_id_all.csv')
    
    # Convert df_all_hpo 'hpo_id' column to a list of all HPO terms
    all_hpo_terms = df_all_hpo['hpo_id'].tolist()
    
    # Apply the function to create the HPO_NOISE column in df_pathway_hposet
    def combine_hpo_noise(row):
        # Select n terms from the HPO_ALL column in df_pathway_hposet
        selected_hpo_all = random_hpo_noise(row['HPO_ALL'], n)
        # Select m terms from the df_all_hpo HPO list
        selected_hpo_noise = random.sample(all_hpo_terms, min(m, len(all_hpo_terms)))
        # Combine and return as a single string with "; " delimiter
        return "; ".join(selected_hpo_all + selected_hpo_noise)

    # Apply the function to each row in df_pathway_hposet
    df_pathway_hposet[f'HPO_{i}'] = df_pathway_hposet['HPO_ALL'].apply(lambda x: random_hpo(x, i))    

    # Add the new column HPO_NOISE to df_pathway_hposet
    df_pathway_hposet['HPO_NOISE'] = df_pathway_hposet.apply(combine_hpo_noise, axis=1)
    
    # Save the result to a csv file
    df_pathway_hposet.to_csv('pathway_hpo.csv')

    return df_pathway_hposet

# %%
# Example usage (assuming df_pathway_hposet and df_all_hpo are defined):
df_pathway_hposet = pathway_hpo(i=5, n=3, m=2)
print(df_pathway_hposet)
# Out:
#     ORPHACODE                                            DISEASE  \
# 0          15                                     Achondroplasia
# 1          15                                     Achondroplasia
# 2          15                                     Achondroplasia
# 3          18                      Distal renal tubular acidosis
# 4          18                      Distal renal tubular acidosis
# 5          18                      Distal renal tubular acidosis
# 6          41              Dyschromatosis symmetrica hereditaria
# 7          41              Dyschromatosis symmetrica hereditaria
# 8          41              Dyschromatosis symmetrica hereditaria
# 9          51                         Aicardi-Goutières syndrome
# 10         51                         Aicardi-Goutières syndrome
# 11         51                         Aicardi-Goutières syndrome
# 12         63                                    Alport syndrome
# 13         63                                    Alport syndrome
# 14         63                                    Alport syndrome
# 15         65                         Leber congenital amaurosis
# 16         65                         Leber congenital amaurosis
# 17         65                         Leber congenital amaurosis
# 18         82  Hereditary thrombophilia due to congenital ant...
# 19         82  Hereditary thrombophilia due to congenital ant...
# 20         82  Hereditary thrombophilia due to congenital ant...
# 21         87                                     Apert syndrome
# 22         87                                     Apert syndrome
# 23         87                                     Apert syndrome
# 24         97                         Familial paroxysmal ataxia
# 25         97                         Familial paroxysmal ataxia
# 26         97                         Familial paroxysmal ataxia
# 27        107                                       BOR syndrome
# 28        107                                       BOR syndrome
# 29        107                                       BOR syndrome
# 30     480536  MSH3-related attenuated familial adenomatous p...
# 31     480536  MSH3-related attenuated familial adenomatous p...
# 32     480536  MSH3-related attenuated familial adenomatous p...
# 33     500533  Polyhydramnios-megalencephaly-symptomatic epil...
# 34     500533  Polyhydramnios-megalencephaly-symptomatic epil...
# 35     500533  Polyhydramnios-megalencephaly-symptomatic epil...
# 36     504476  Cerebellar ataxia with neuropathy and bilatera...
# 37     504476  Cerebellar ataxia with neuropathy and bilatera...
# 38     504476  Cerebellar ataxia with neuropathy and bilatera...
# 39     521406   Dystonia-parkinsonism-hypermanganesemia syndrome
#
# 58  HP:0000369; HP:0012448; HP:0033725; HP:0000232...
# 59  HP:0009062; HP:0002353; HP:0000252; HP:0000054...

# %%
print(df_pathway_hposet.head(1))
# Out:
#    ORPHACODE         DISEASE  \
# 0         15  Achondroplasia
#
#                                              HPO_ALL  \
# 0  HP:0001513; HP:0000463; HP:0011867; HP:0000238...
#
#                                                HPO_5  \
# 0  HP:0002938; HP:0000256; HP:0008905; HP:0003375...
#
#                                            HPO_NOISE
# 0  HP:0012418; HP:0010536; HP:0001513; HP:6000754...

# %%
# Access and print values from the first row for specific columns
hpo_all = df_pathway_hposet.loc[0, 'HPO_ALL']
hpo_5 = df_pathway_hposet.loc[0, 'HPO_5']
hpo_noise = df_pathway_hposet.loc[0, 'HPO_NOISE']

# %%
print(hpo_all)
print(hpo_5)
print(hpo_noise)
# Out:
# HP:0001513; HP:0000463; HP:0011867; HP:0000238; HP:0005819; HP:0003498; HP:0001377; HP:0001156; HP:0005257; HP:0012418; HP:0008445; HP:0002091; HP:0005280; HP:0005619; HP:0003416; HP:0003375; HP:0000956; HP:0010536; HP:0008905; HP:0045086; HP:0002808; HP:0000242; HP:0011452; HP:0000365; HP:0003180; HP:0000260; HP:0008947; HP:0004060; HP:0045087; HP:0002979; HP:0000256; HP:0009826; HP:0003194; HP:0002938; HP:0000309; HP:0002007; HP:0003026; HP:0002870; HP:0010241
# HP:0002938; HP:0000256; HP:0008905; HP:0003375; HP:0000242
# HP:0012418; HP:0010536; HP:0001513; HP:6000754; HP:0030142

# %%
print(hpo_all)
# Out:
# HP:0001513; HP:0000463; HP:0011867; HP:0000238; HP:0005819; HP:0003498; HP:0001377; HP:0001156; HP:0005257; HP:0012418; HP:0008445; HP:0002091; HP:0005280; HP:0005619; HP:0003416; HP:0003375; HP:0000956; HP:0010536; HP:0008905; HP:0045086; HP:0002808; HP:0000242; HP:0011452; HP:0000365; HP:0003180; HP:0000260; HP:0008947; HP:0004060; HP:0045087; HP:0002979; HP:0000256; HP:0009826; HP:0003194; HP:0002938; HP:0000309; HP:0002007; HP:0003026; HP:0002870; HP:0010241

# %%
hpo_all = df_pathway_hposet.loc[2, 'HPO_ALL']
hpo_5 = df_pathway_hposet.loc[2, 'HPO_5']
hpo_noise = df_pathway_hposet.loc[2, 'HPO_NOISE']

# %%
print(hpo_all)
print(hpo_5)
print(hpo_noise)
# Out:
# HP:0001513; HP:0000463; HP:0011867; HP:0000238; HP:0005819; HP:0003498; HP:0001377; HP:0001156; HP:0005257; HP:0012418; HP:0008445; HP:0002091; HP:0005280; HP:0005619; HP:0003416; HP:0003375; HP:0000956; HP:0010536; HP:0008905; HP:0045086; HP:0002808; HP:0000242; HP:0011452; HP:0000365; HP:0003180; HP:0000260; HP:0008947; HP:0004060; HP:0045087; HP:0002979; HP:0000256; HP:0009826; HP:0003194; HP:0002938; HP:0000309; HP:0002007; HP:0003026; HP:0002870; HP:0010241
# HP:0002007; HP:0008445; HP:0010536; HP:0008947; HP:0000238
# HP:0005257; HP:0005819; HP:0010241; HP:0002296; HP:0011316
